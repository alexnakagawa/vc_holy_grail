# %%
import pandas as pd

# %%
df = pd.read_json("./data/crunchbase_profiles_1k.jl", lines = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 999
# Data columns (total 30 columns):
# _key                                    1000 non-null object
# boards_and_advisor_roles                134 non-null object
# boards_and_advisor_roles_urls           133 non-null object
# born                                    139 non-null object
# description                             525 non-null object
# education                               262 non-null object
# education_urls                          258 non-null object
# events                                  106 non-null object
# events_urls                             106 non-null object
# gender                                  973 non-null object
# images                                  980 non-null object
# investments                             39 non-null object
# investments_urls                        38 non-null object
# jobs                                    844 non-null object
# ...

# %%
df
# Out:
#                  _key                           boards_and_advisor_roles  \
# 0    2b3bf23e986acd98                                                NaN
# 1    d6eba9f912c6d6ce                                                NaN
# 2    1806cfe6eef3605f                                                NaN
# 3    785e17a252ef0458                                                NaN
# 4    9242987915cd2f88                                                NaN
# 5    c854feccc644eb28                                                NaN
# 6    e86671327ceb38ef  [{'organization': {'url': 'https://www.crunchb...
# 7    874f7c0237e073ab                                                NaN
# 8    b2059b46653aa224                                                NaN
# 9    b7fd5092d22bcf3f                                                NaN
# 10   34e1f0d140a02f30  [{'organization': {'url': 'https://www.crunchb...
# 11   230e8fefd8abb416                                                NaN
# ...

# %%
print(df["primary_role"])
# Out:
# 0                              VP Engineering @ Parrable
# 1                                 Founder @ STRAKERFILMS
# 2      Executive Vice President & Chief Human Resourc...
# 3                                        CIO @ TeamLINKS
# 4                               SVP, Enterprise @ Upwork
# 5                                         Founder @ Synx
# 6                                                    NaN
# 7                President & COO @ Credentials Solutions
# 8            Co-founder, Senior Vice President @ Gateway
# 9                         Product Director @ Hello Heart
# 10                    VP Business Development @ MyCosmik
# 11                                                   NaN
# 12                                                   NaN
# 13                                                   NaN
# 14              Business Development Manager @ myDevices
# 15                      Web Designer @ First Scribe Inc.
# ...

# %%
df_education = pd.read_json((df["education"]).to_json(), orient="index")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-f1a06b849d55> in <module>()
# ----> 1 df_education = pd.read_json((df["education"]).to_json(), orient="index")
#
# /anaconda/lib/python3.6/site-packages/pandas/io/json/json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines)
#     352         obj = FrameParser(json, orient, dtype, convert_axes, convert_dates,
#     353                           keep_default_dates, numpy, precise_float,
# --> 354                           date_unit).parse()
#     355
#     356     if typ == 'series' or obj is None:
#
# /anaconda/lib/python3.6/site-packages/pandas/io/json/json.py in parse(self)
#     420
#     421         else:
# --> 422             self._parse_no_numpy()
#     423
#     424         if self.obj is None:
#
# ...
